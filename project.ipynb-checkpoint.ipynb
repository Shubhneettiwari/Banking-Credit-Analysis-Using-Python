# %% [markdown]
#  OBJECTIVE:
#
# Machine learning is a critical step in the discovery of  informations that includes theories,methodologies and instruments to reveal petterns in data
#
# It is essential to know rationale behind the techniques so that instruments and techniques fit tha data and pattern recognition goal properly.there may be several choices available for the dataset.

# %%
#Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
#load dataset
url = "https://www.kaggle.com/janiobachmann/bank-marketing-dataset"
names = ['age','job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','deposit']
dataset = pd.read_csv(url, names=names)

# %% [markdown]
# Dimensions of Dataset

# %%
# shape
print(dataset.shape)
# Out:
# (248, 17)

# %%
# detail about data
dataset.dtypes
# Out:
# age          object
# job          object
# marital      object
# education    object
# default      object
# balance      object
# housing      object
# loan         object
# contact      object
# day          object
# month        object
# duration     object
# campaign     object
# pdays        object
# previous     object
# poutcome     object
# deposit      object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 17 columns):
# age          248 non-null object
# job          25 non-null object
# marital      14 non-null object
# education    12 non-null object
# default      8 non-null object
# balance      7 non-null object
# housing      5 non-null object
# loan         4 non-null object
# contact      3 non-null object
# day          2 non-null object
# month        2 non-null object
# duration     2 non-null object
# campaign     2 non-null object
# pdays        2 non-null object
# previous     2 non-null object
# poutcome     2 non-null object
# deposit      2 non-null object
# dtypes: object(17)
# memory usage: 16.5+ KB

# %% [markdown]
# Peek at the Data

# %%
dataset.head(30)
# Out:
#                                                   age  \
# 0                                     <!DOCTYPE html>
# 1                                    <html lang="en">
# 2                                              <head>
# 3       <title>Bank Marketing Dataset | Kaggle</ti...
# 4                            <meta charset="utf-8" />
# 5                  <meta name="robots" content="index
# 6       <meta name="turbolinks-cache-control" cont...
# 7               <meta name="keywords" content="cla...
# 8                     <script type="text/javascript">
# 9           window["initialPageLoadStartTime"] = n...
# 10                                          </script>
# 11      <link rel="dns-prefetch" href="https://www...
# 12      <link href="/static/images/favicon.ico" re...
# 13      <link rel="manifest" href="/static/json/ma...
# 14      <link href="//fonts.googleapis.com/css?fam...
# 15      <link href="https://fonts.googleapis.com/i...
# ...

# %% [markdown]
# Statistical Summary

# %%
# descriptions
dataset.describe()
# Out:
#               age              job             marital  \
# count         248               25                  14
# unique        215               25                  14
# top     </script>  c);h.timeout=c;   initial-scale=1.0
# freq            6                1                   1
#
#                               education                              default  \
# count                                12                                    8
# unique                               12                                    8
# top     discussion:{"canDownvote":false  dataUrl:"/forums/10189/topics.json"
# freq                                  1                                    1
#
#           balance            housing       loan  \
# count           7                  5          4
# unique          7                  5          4
# top     600italic  isRootLevel:false   Elsevier
# freq            1                  1          1
#
# ...

# %%
# class distribution
dataset.groupby('month').size()
# Out:
# month
# initialTopics:null                                                   1
# url:"https://www.kaggle.com/janiobachmann/bank-marketing-dataset"    1
# dtype: int64

# %% [markdown]
# sklearn requires all inputs to be numeric, we should convert all our categorical variables into numeric by encoding the categories.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
var_mod = ['age','job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','deposit']
le = LabelEncoder()
for i in var_mod:
    dataset[i] =le.fit_transform(dataset[i].astype(str))

# %% [markdown]
# SPILTING THE DATASET

# %%
array = dataset.values
X = array[:,6:11]
Y = array[:,12]
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=17)

# %%
x_train.shape
# Out:
# (198, 5)

# %%
#Evaluating the model and training the Model

# %% [markdown]
# Logistic Regression : Logistic Regression is a classification algorithm. It is used to predict a binary outcome (1 / 0, Yes / No, True / False) given a set of independent variables. To represent binary / categorical outcome, we use dummy variables

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
predictions = model.predict(x_test)
print(accuracy_score(y_test, predictions))
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.98

# %% [markdown]
# Decision tree : Decision tree is a type of supervised learning algorithm (having a pre-defined target variable) that is mostly used in classification problems. It works for both categorical and continuous input and output variables

# %%
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
predictions = model.predict(x_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.98

# %% [markdown]
# Random forest : Random forests or random decision forests are an ensemble learning method for classification, regression and other tasks, that operate by constructing a multitude of decision trees at training time and outputting the class that is the mode of the classes (classification) or mean prediction (regression) of the individual trees

# %%
model = RandomForestClassifier(n_estimators=100)
model.fit(x_train,y_train)
predictions = model.predict(x_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.98

# %% [markdown]
# SOME PLOTTINGS:

# %%
# Histogram of Profit
plt.figure(figsize=(10,5))
plt.hist(dataset["loan"],color="blue", bins=10)
plt.hist(dataset["deposit"],color="red",bins=10)
plt.hist(dataset["balance"],color="green",bins=10)
plt.hist(dataset["duration"],color="yellow",bins=10)
plt.xlabel('outcome')
plt.ylabel('Frequency')
plt.title('Bank Marketing', size=24)
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dataset[['age','job','default','balance','loan','day','month','duration','pdays','deposit']] , figsize = (20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0A8DBB70>,
# ...
#       dtype=object)

# %%
dataset.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0E04C4D0>,
# ...
#       dtype=object)

# %%
# scatter plot matrix
scatter_matrix(dataset)
plt.show()
